# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport
import re
import seaborn as sns
from wordcloud import WordCloud
from pathlib import Path

import warnings
warnings.filterwarnings(action='ignore')

# %%
rawd = pd.read_csv(r"D:\A.AI.ML\Projects\flipkart_sales\artefacts\raw\Flipkart_Mobiles.csv")
df = rawd.copy()

# %% [markdown]
# ### Data Cleaning

# %%
df1_cols = [] 
for i in df1.columns: 

    df1_cols.append(i.lower())

df2_cols = [] 
for i in df2.columns: 

    df2_cols.append(i.lower())   

df1_cols = [x.replace(" ", "_") for x in df1_cols]
df2_cols = [x.replace(" ", "_") for x in df2_cols]

df1.columns = df1_cols
df2.columns = df2_cols

# %%
df_sales = pd.concat([df1, df2])
df_sales
# Out:
#        brand      model            color memory storage  rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       selling_price  original_price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
df_sales = df_sales.drop_duplicates()
df_sales.reset_index(inplace = True, drop = True)
df_sales
# Out:
#        brand      model            color memory storage  rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 4684  Xiaomi  Redmi Y2         Rose Gold   3 GB   32 GB     4.3
# 4685  Xiaomi  Redmi Y2         Rose Gold   4 GB   64 GB     0.0
# 4686  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 4687  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 4688  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
#
#       selling_price  original_price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
cols = df_sales.columns
num_cols = list(df_sales._get_numeric_data().columns)
cat_cols = list(set(cols) - set(num_cols))

print("Num Cols:", num_cols, "\n")
print("Cat Cols:", cat_cols)
# Out:
# Num Cols: ['rating', 'selling_price', 'original_price']
#
# Cat Cols: ['model', 'brand', 'storage', 'color', 'memory']

# %% [markdown]
# #### Observations

# %%
print("No of observations in the data:_", df_sales.shape[0])
print("No of features in the data:_ ",df_sales.shape[1])
# Out:
# No of observations in the data:_ 4689
# No of features in the data:_  8

# %%
df_sales.dtypes
# Out:
# brand              object
# model              object
# color              object
# memory             object
# storage            object
# rating            float64
# selling_price     float64
# original_price    float64
# dtype: object

# %%
df_sales.isna().sum()[df_sales.isna().sum()>0]
# Out:
# model                2
# color              133
# memory              77
# storage             95
# rating             130
# selling_price        3
# original_price    1606
# dtype: int64

# %%
round(df_sales.isna().sum()[df_sales.isna().sum()>0]*100/df_sales.shape[0], 2)
# Out:
# model              0.04
# color              2.84
# memory             1.64
# storage            2.03
# rating             2.77
# selling_price      0.06
# original_price    34.25
# dtype: float64

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df_sales.isna())
plt.show()

# %%
df_sales.nunique()
# Out:
# brand              17
# model             914
# color             654
# memory             31
# storage            33
# rating             26
# selling_price     844
# original_price    819
# dtype: int64

# %%
round(df_sales.nunique()*100/df_sales.shape[0], 2)
# Out:
# brand              0.36
# model             19.49
# color             13.95
# memory             0.66
# storage            0.70
# rating             0.55
# selling_price     18.00
# original_price    17.47
# dtype: float64

# %%
df_sales = df_sales.dropna()
df_sales.shape
# Out:
# (2851, 8)

# %% [markdown]
# ### Eda

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# #### 1. Brand

# %%
print(f"No of unique brands available are:_{df_sales['brand'].nunique()}")
# Out:
# No of unique brands available are:_17

# %%
df = pd.DataFrame(np.round(df_sales['brand'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['brand','count_perc']

# %%
sns.barplot(df.brand, df.count_perc)
plt.xticks(rotation = 90)
plt.show()

# %%
# Out:
# No of unique brands available are:_885

# %% [markdown]
# #### 2. Model

# %%
print(f"No of unique models available are:_{df_sales['model'].nunique()}")
# Out:
# No of unique models available are:_914

# %%
df = pd.DataFrame(np.round(df_sales['model'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['Model','count_perc']

# %%
df.head(5)
# Out:
#                Model  count_perc
# 0                  3        0.88
# 1  iPhone 13 Pro Max        0.67
# 2         iPhone 11         0.67
# 3         iPhone 12         0.63
# 4        Galaxy A12         0.63

# %%
df.tail(5)
# Out:
#                    Model  count_perc
# 880                 P70         0.04
# 881                S560         0.04
# 882  Zenfone Go 5.0 LTE         0.04
# 883                A328         0.04
# 884           S20 FE 5G         0.04

# %% [markdown]
# #### 3. Color

# %%
print(f"No of unique brands available are:_{df_sales['color'].nunique()}")
# Out:
# No of unique brands available are:_630

# %%
df = pd.DataFrame(np.round(df_sales['color'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['Color','count_perc']

# %%
df.head(10)
# Out:
#             Color  count_perc
# 0           Black       15.08
# 1            Gold        6.17
# 2           White        5.19
# 3            Blue        4.56
# 4          Silver        2.95
# 5             Red        2.31
# 6            Grey        1.51
# 7  Midnight Black        1.23
# 8      Space Grey        1.09
# 9       Rose Gold        0.95

# %%
clrs = []
for clr in df_sales.color.str.split():
    clrs.extend(clr)
    
text = ' '.join(clrs)

# %%
word_cloud = WordCloud(collocations=False, background_color='white').generate(text)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
ctr = Counter(text.split())
top_nine_colors = ctr.most_common(9)
print(top_nine_colors)
# Out:
# [('Black', 820), ('Blue', 510), ('White', 298), ('Gold', 278), ('Silver', 167), ('Grey', 135), ('Green', 131), ('Red', 127), ('Purple', 63)]

# %%
clr_to_check = [x for (x,y) in top_nine_colors]

# %%
#If there are if statments, read the if statements first

df_sales['base_colors'] = df_sales['color'].str.split().apply(lambda x:[i for i in x if i in clr_to_check]) #midnight black, removes midnight and gives black and black is a list
df_sales['base_colors'] = df_sales['base_colors'].apply(lambda x: ['others'] if x==[] else x) #replaces emply lists with others
df_sales['base_colors'] =  df_sales['base_colors'].apply(lambda x:' '.join(x))

# %%
df = pd.DataFrame(np.round(df_sales['base_colors'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['Base_colors','count_perc']
df.head(10)
# Out:
#   Base_colors  count_perc
# 0       Black       28.48
# 1        Blue       17.68
# 2      others       11.82
# 3       White       10.42
# 4        Gold        9.51
# 5      Silver        5.61
# 6        Grey        4.70
# 7       Green        4.59
# 8         Red        4.45
# 9      Purple        2.21

# %% [markdown]
# #### 4. Memory

# %%
print(f"No of unique brands available are:_{df_sales['memory'].nunique()}")
# Out:
# No of unique brands available are:_31

# %%
df = pd.DataFrame(np.round(df_sales['memory'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['Memory','count_perc']
df.head(9)
# Out:
#   Memory  count_perc
# 0   4 GB       24.22
# 1   3 GB       17.11
# 2   6 GB       14.72
# 3   2 GB       13.62
# 4   8 GB        9.35
# 5   1 GB        7.61
# 6    4GB        3.43
# 7   4 MB        1.69
# 8  12 GB        1.63

# %%
sns.barplot(df.Memory, df.count_perc)
plt.xticks(rotation = 90)
plt.show()

# %%
df_sales['memory_num'] = (df_sales['memory'].astype(str).apply(lambda x: ''.join(re.findall('\d+',x)))).astype(int)
df_sales['memory_type'] = df_sales['memory'].astype(str).apply(lambda x: ''.join(re.findall('[a-zA-Z]+',x)))

# %%
df_sales['memory_num'].describe()
# Out:
# count    2851.000000
# mean       14.951596
# std        72.979452
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max       768.000000
# Name: memory_num, dtype: float64

# %%
df_sales['memory_num'].quantile(q=[0.8,0.9,0.95])
# Out:
# 0.80     6.0
# 0.90     8.0
# 0.95    12.0
# Name: memory_num, dtype: float64

# %%
sns.boxplot(df_sales['memory_num']) #Inter quantile range - box and whiskers plot 
plt.show()

# %% [markdown]
# ### 5. Storage

# %%
print(f"No of unique brands available are:_{df_sales['storage'].nunique()}")
# Out:
# No of unique brands available are:_26

# %%
df = pd.DataFrame(np.round(df_sales['storage'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['storage','count_perc']

# %%
sns.barplot(df.storage, df.count_perc)
plt.xticks(rotation = 90)
plt.show()

# %%
df_sales['storage_num'] = (df_sales['storage'].astype(str).apply(lambda x: ''.join(re.findall('\d+',x)))).astype(int)
#sales['Storage_type'] = sales['Storage'].astype(str).apply(lambda x: ''.join(re.findall('[a-zA-Z]+',x)))

# %%
df_sales['storage_num'].describe()
# Out:
# count    2851.000000
# mean       83.330761
# std        82.522446
# min         1.000000
# 25%        32.000000
# 50%        64.000000
# 75%       128.000000
# max       512.000000
# Name: storage_num, dtype: float64

# %%
df_sales['storage_num'].quantile(q=[0.8,0.9,0.95])
# Out:
# 0.80    128.0
# 0.90    128.0
# 0.95    256.0
# Name: storage_num, dtype: float64

# %%
sns.boxplot(df_sales['storage_num'])
plt.show()

# %% [markdown]
# #### 6. Rating

# %%
print(f"No of unique brands available are:_{df_sales['rating'].nunique()}")
# Out:
# No of unique brands available are:_26

# %%
df = pd.DataFrame(np.round(df_sales['rating'].value_counts(normalize=True)*100, 2)).reset_index()
df.columns=['rating','count_perc']

# %%
sns.barplot(df.rating, df.count_perc)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 7. Original Price

# %%
print(f"No of unique brands available are:_{df_sales['original_price'].nunique()}")
# Out:
# No of unique brands available are:_794

# %%
df_sales['original_price'].describe()
# Out:
# count      2851.000000
# mean      25751.964925
# std       27434.504876
# min        1000.000000
# 25%        9999.000000
# 50%       15999.000000
# 75%       28989.500000
# max      189999.000000
# Name: original_price, dtype: float64

# %%
df_sales['original_price'].quantile(q=[0.8,0.9,0.95])
# Out:
# 0.80    34900.0
# 0.90    59900.0
# 0.95    84900.0
# Name: original_price, dtype: float64

# %%
sns.boxplot(df_sales['original_price'])
plt.show()

# %% [markdown]
# #### 8. Selling Price

# %%
print(f"No of unique brands available are:_{df_sales['selling_price'].nunique()}")
# Out:
# No of unique brands available are:_816

# %%
df_sales['selling_price'].describe()
# Out:
# count      2851.000000
# mean      23810.998597
# std       25538.861281
# min        1000.000000
# 25%        9900.000000
# 50%       14999.000000
# 75%       25990.000000
# max      179900.000000
# Name: selling_price, dtype: float64

# %%
df_sales['selling_price'].quantile(q=[0.8,0.9,0.95])
# Out:
# 0.80    30990.0
# 0.90    54990.0
# 0.95    74999.0
# Name: selling_price, dtype: float64

# %%
sns.boxplot(df_sales['selling_price'])
plt.show()

# %% [markdown]
# #### 9. Discount

# %%
df_sales['discount'] = round((df_sales['original_price'] - df_sales['selling_price'])*100/df_sales['selling_price'] , 2)

# %%
df_sales['discount'].describe()
# Out:
# count    2851.000000
# mean        9.016689
# std        20.174303
# min       -61.590000
# 25%         0.000000
# 50%         0.000000
# 75%        11.110000
# max       240.260000
# Name: discount, dtype: float64

# %%
df_sales['discount'].quantile(q=[0.6,0.7,0.8,0.9,0.95])
# Out:
# 0.60     0.00
# 0.70     8.57
# 0.80    15.40
# 0.90    25.93
# 0.95    37.52
# Name: discount, dtype: float64

# %%
sns.boxplot(df_sales['discount'])
plt.show()

# %% [markdown]
# #### Bivariate Analysis

# %%
df_sales
# Out:
#        brand          model            color memory storage  rating  \
# 0       OPPO            A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO            A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO            A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO            A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO            A53   Electric Black   4 GB   64 GB     4.5
# ...      ...            ...              ...    ...     ...     ...
# 4556    POCO   M2 Reloaded     Greyish Black   4 GB   64 GB     4.3
# 4600  Xiaomi         Mi A3     Not just Blue   4 GB   64 GB     0.0
# 4656  Xiaomi  Redmi Note 7        Onyx Black   3 GB   32 GB     0.0
# 4671  Xiaomi  REDMI Note 9        Aqua Green   4 GB   64 GB     0.0
# 4672  Xiaomi  REDMI Note 9      Shadow Black   4 GB   64 GB     0.0
#
#       selling_price  original_price base_colors  memory_num memory_type  \
# 0           11990.0         15990.0       Black           4          GB
# ...

# %%
sns.pairplot(df_sales)
plt.show()

# %%
sns.pairplot(df_sales, hue='memory_type')
plt.show()

# %%
df_sales.corr()
# Out:
#                   rating  selling_price  original_price  memory_num  \
# rating          1.000000       0.237047        0.230161   -0.098599
# selling_price   0.237047       1.000000        0.981406   -0.091514
# original_price  0.230161       0.981406        1.000000   -0.092072
# memory_num     -0.098599      -0.091514       -0.092072    1.000000
# storage_num     0.175738       0.643758        0.643373   -0.069242
# discount       -0.017349      -0.039994        0.094368    0.013079
#
#                 storage_num  discount
# rating             0.175738 -0.017349
# selling_price      0.643758 -0.039994
# original_price     0.643373  0.094368
# memory_num        -0.069242  0.013079
# storage_num        1.000000  0.043171
# discount           0.043171  1.000000

# %%
df_sales
# Out:
#        brand          model            color memory storage  rating  \
# 0       OPPO            A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO            A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO            A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO            A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO            A53   Electric Black   4 GB   64 GB     4.5
# ...      ...            ...              ...    ...     ...     ...
# 4556    POCO   M2 Reloaded     Greyish Black   4 GB   64 GB     4.3
# 4600  Xiaomi         Mi A3     Not just Blue   4 GB   64 GB     0.0
# 4656  Xiaomi  Redmi Note 7        Onyx Black   3 GB   32 GB     0.0
# 4671  Xiaomi  REDMI Note 9        Aqua Green   4 GB   64 GB     0.0
# 4672  Xiaomi  REDMI Note 9      Shadow Black   4 GB   64 GB     0.0
#
#       selling_price  original_price base_colors  memory_num memory_type  \
# 0           11990.0         15990.0       Black           4          GB
# ...

# %%
file_path = Path(r"D:\A.AI.ML\Projects\flipkart_sales\artefacts\processed\flipkart_mobile_sales_fe.csv", index = False)
df_sales.to_csv(file_path)
